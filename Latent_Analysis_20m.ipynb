# %%
import argparse
from utils.io import load_numpy
import numpy as np
from experiment.latent_analysis import latent_analysis
from experiment.popular_analysis import popular_overlapping
from utils.argument import shape
from utils.argument import check_float_positive, check_int_positive, shape

from models.lrec import embedded_lrec_items
from models.weighted_lrec import weighted_lrec_items
from models.pure_svd import pure_svd, eigen_boosted_pure_svd
from models.als import als
from models.pmi_lrec import pmi_lrec_items
from models.weighted_pmi_lrec import weighted_pmi_lrec_items
from models.chainitemitem import chain_item_item
from models.predictor import predict
import pandas as pd
# Out:
# /usr/local/lib/python2.7/dist-packages/ipywidgets/widgets/widget.py:281: DeprecationWarning:
#
# Widget registration using a string name has been deprecated. Widget registration now uses a plain `@register` decorator.

# %%
argpath = 'data/'
argtrain = 'Rtrain.npz'
argvalid = 'Rvalid.npz'
argindex = 'Index.npy'
argside = 'ml-20m/movies.csv'

# %%
R_train = load_numpy(path=argpath, name=argtrain)
Index = np.load(argpath+argindex)
Side_info = pd.read_csv(argpath+argside, delimiter=',', encoding='utf-8')

# %%
Side_info
# Out:
#        movieId                                              title  \
# 0            1                                   Toy Story (1995)
# 1            2                                     Jumanji (1995)
# 2            3                            Grumpier Old Men (1995)
# 3            4                           Waiting to Exhale (1995)
# 4            5                 Father of the Bride Part II (1995)
# 5            6                                        Heat (1995)
# 6            7                                     Sabrina (1995)
# 7            8                                Tom and Huck (1995)
# 8            9                                Sudden Death (1995)
# 9           10                                   GoldenEye (1995)
# 10          11                     American President, The (1995)
# 11          12                 Dracula: Dead and Loving It (1995)
# 12          13                                       Balto (1995)
# 13          14                                       Nixon (1995)
# 14          15                            Cutthroat Island (1995)
# 15          16                                      Casino (1995)
# 16          17                       Sense and Sensibility (1995)
# 17          18                                  Four Rooms (1995)
# 18          19              Ace Ventura: When Nature Calls (1995)
# 19          20                                 Money Train (1995)
# 20          21                                  Get Shorty (1995)
# 21          22                                     Copycat (1995)
# 22          23                                   Assassins (1995)
# 23          24                                      Powder (1995)
# 24          25                           Leaving Las Vegas (1995)
# 25          26                                     Othello (1995)
# 26          27                                Now and Then (1995)
# 27          28                                  Persuasion (1995)
# 28          29  City of Lost Children, The (Cité des enfants p...
# 29          30  Shanghai Triad (Yao a yao yao dao waipo qiao) ...
# ...        ...                                                ...
# 27248   131146                      Werner - Volles Rooäää (1999)
# 27249   131148                                  What A Man (2011)
# 27250   131150         7 Dwarves: The Forest Is Not Enough (2006)
# 27251   131152                                 The Fat Spy (1966)
# 27252   131154  Die Bademeister – Weiber, saufen, Leben retten...
# 27253   131156                         Ants in the Pants 2 (2002)
# 27254   131158                                Manta, Manta (1991)
# 27255   131160                  Oscar and the Lady in Pink (2009)
# 27256   131162                      Por un puñado de besos (2014)
# 27257   131164                               Vietnam in HD (2011)
# 27258   131166                                  WWII IN HD (2009)
# 27259   131168                                     Phoenix (2014)
# 27260   131170                                   Parallels (2015)
# 27261   131172                              Closed Curtain (2013)
# 27262   131174                                   Gentlemen (2014)
# 27263   131176                             A Second Chance (2014)
# 27264   131180                     Dead Rising: Watchtower (2015)
# 27265   131231                                     Standby (2014)
# 27266   131237                         What Men Talk About (2010)
# 27267   131239                          Three Quarter Moon (2011)
# 27268   131241                           Ants in the Pants (2000)
# 27269   131243                Werner - Gekotzt wird später (2003)
# 27270   131248                              Brother Bear 2 (2006)
# 27271   131250                              No More School (2000)
# 27272   131252  Forklift Driver Klaus: The First Day on the Jo...
# 27273   131254                       Kein Bund für's Leben (2007)
# 27274   131256                      Feuer, Eis & Dosenbier (2002)
# 27275   131258                                 The Pirates (2014)
# 27276   131260                                Rentun Ruusu (2001)
# 27277   131262                                   Innocence (2014)
#
#                                             genres
# 0      Adventure|Animation|Children|Comedy|Fantasy
# 1                       Adventure|Children|Fantasy
# 2                                   Comedy|Romance
# 3                             Comedy|Drama|Romance
# 4                                           Comedy
# 5                            Action|Crime|Thriller
# 6                                   Comedy|Romance
# 7                               Adventure|Children
# 8                                           Action
# 9                        Action|Adventure|Thriller
# 10                            Comedy|Drama|Romance
# 11                                   Comedy|Horror
# 12                    Adventure|Animation|Children
# 13                                           Drama
# 14                        Action|Adventure|Romance
# 15                                     Crime|Drama
# 16                                   Drama|Romance
# 17                                          Comedy
# 18                                          Comedy
# 19              Action|Comedy|Crime|Drama|Thriller
# 20                           Comedy|Crime|Thriller
# 21             Crime|Drama|Horror|Mystery|Thriller
# 22                           Action|Crime|Thriller
# 23                                    Drama|Sci-Fi
# 24                                   Drama|Romance
# 25                                           Drama
# 26                                  Children|Drama
# 27                                   Drama|Romance
# 28          Adventure|Drama|Fantasy|Mystery|Sci-Fi
# 29                                     Crime|Drama
# ...                                            ...
# 27248                             Animation|Comedy
# 27249                               Comedy|Romance
# 27250                                       Comedy
# 27251                                       Comedy
# 27252                                       Comedy
# 27253                                       Comedy
# 27254                                       Comedy
# 27255                                        Drama
# 27256                                Drama|Romance
# 27257                                          War
# 27258                           (no genres listed)
# 27259                                        Drama
# 27260                                       Sci-Fi
# 27261                           (no genres listed)
# 27262                       Drama|Romance|Thriller
# 27263                                        Drama
# 27264                       Action|Horror|Thriller
# 27265                               Comedy|Romance
# 27266                                       Comedy
# 27267                                 Comedy|Drama
# 27268                               Comedy|Romance
# 27269                             Animation|Comedy
# 27270  Adventure|Animation|Children|Comedy|Fantasy
# 27271                                       Comedy
# 27272                                Comedy|Horror
# 27273                                       Comedy
# 27274                                       Comedy
# 27275                                    Adventure
# 27276                           (no genres listed)
# 27277                     Adventure|Fantasy|Horror
#
# [27278 rows x 3 columns]

# %%
R_train.shape
# Out:
# (138494, 22884)

# %%
Side_info.size
# Out:
# 81834

# %%
np.asarray(np.sum(R_train,axis=0)).reshape(-1).shape
# Out:
# (22884,)

# %%
Side_info = Side_info[Side_info['movieId'].isin(Index)].reset_index(drop=True)

# %%
Side_info['popularity'] = np.asarray(np.sum(R_train,axis=0)).reshape(-1)

# %%
Side_info['notes'] = Side_info['title'] + '<br>' + Side_info['genres'] + '<br>Popularity:' +  Side_info['popularity'].astype(str)

# %%
Side_info
# Out:
#        movieId                                              title  \
# 0            1                                   Toy Story (1995)
# 1            2                                     Jumanji (1995)
# 2            3                            Grumpier Old Men (1995)
# 3            4                           Waiting to Exhale (1995)
# 4            5                 Father of the Bride Part II (1995)
# 5            6                                        Heat (1995)
# 6            7                                     Sabrina (1995)
# 7            8                                Tom and Huck (1995)
# 8            9                                Sudden Death (1995)
# 9           10                                   GoldenEye (1995)
# 10          11                     American President, The (1995)
# 11          12                 Dracula: Dead and Loving It (1995)
# 12          13                                       Balto (1995)
# 13          14                                       Nixon (1995)
# 14          15                            Cutthroat Island (1995)
# 15          16                                      Casino (1995)
# 16          17                       Sense and Sensibility (1995)
# 17          18                                  Four Rooms (1995)
# 18          19              Ace Ventura: When Nature Calls (1995)
# 19          20                                 Money Train (1995)
# 20          21                                  Get Shorty (1995)
# 21          22                                     Copycat (1995)
# 22          23                                   Assassins (1995)
# 23          24                                      Powder (1995)
# 24          25                           Leaving Las Vegas (1995)
# 25          26                                     Othello (1995)
# 26          27                                Now and Then (1995)
# 27          28                                  Persuasion (1995)
# 28          29  City of Lost Children, The (Cité des enfants p...
# 29          30  Shanghai Triad (Yao a yao yao dao waipo qiao) ...
# ...        ...                                                ...
# 22854   131132                Kleines Arschloch - Der Film (1997)
# 22855   131134                            Manta - Der Film (1991)
# 22856   131136                                Girls on Top (2001)
# 22857   131138                                   My Führer (2007)
# 22858   131140                            Stopped on Track (2011)
# 22859   131142                               Voll Normaaal (1994)
# 22860   131144                Werner - Das muss kesseln!!! (1996)
# 22861   131146                      Werner - Volles Rooäää (1999)
# 22862   131148                                  What A Man (2011)
# 22863   131150         7 Dwarves: The Forest Is Not Enough (2006)
# 22864   131154  Die Bademeister – Weiber, saufen, Leben retten...
# 22865   131156                         Ants in the Pants 2 (2002)
# 22866   131158                                Manta, Manta (1991)
# 22867   131160                  Oscar and the Lady in Pink (2009)
# 22868   131164                               Vietnam in HD (2011)
# 22869   131166                                  WWII IN HD (2009)
# 22870   131168                                     Phoenix (2014)
# 22871   131170                                   Parallels (2015)
# 22872   131174                                   Gentlemen (2014)
# 22873   131176                             A Second Chance (2014)
# 22874   131231                                     Standby (2014)
# 22875   131239                          Three Quarter Moon (2011)
# 22876   131241                           Ants in the Pants (2000)
# 22877   131243                Werner - Gekotzt wird später (2003)
# 22878   131248                              Brother Bear 2 (2006)
# 22879   131250                              No More School (2000)
# 22880   131252  Forklift Driver Klaus: The First Day on the Jo...
# 22881   131254                       Kein Bund für's Leben (2007)
# 22882   131256                      Feuer, Eis & Dosenbier (2002)
# 22883   131262                                   Innocence (2014)
#
#                                             genres  popularity  \
# 0      Adventure|Animation|Children|Comedy|Fantasy     25021.0
# 1                       Adventure|Children|Fantasy      4298.0
# 2                                   Comedy|Romance      2570.0
# 3                             Comedy|Drama|Romance       230.0
# 4                                           Comedy      2070.0
# 5                            Action|Crime|Thriller      9082.0
# 6                                   Comedy|Romance      2951.0
# 7                               Adventure|Children       129.0
# 8                                           Action       381.0
# 9                        Action|Adventure|Thriller      8914.0
# 10                            Comedy|Drama|Romance      5706.0
# 11                                   Comedy|Horror       408.0
# 12                    Adventure|Animation|Children       257.0
# 13                                           Drama      1343.0
# 14                        Action|Adventure|Romance       213.0
# 15                                     Crime|Drama      6218.0
# 16                                   Drama|Romance      9778.0
# 17                                          Comedy      1221.0
# 18                                          Comedy      2888.0
# 19              Action|Comedy|Crime|Drama|Thriller       349.0
# 20                           Comedy|Crime|Thriller      8110.0
# 21             Crime|Drama|Horror|Mystery|Thriller      1963.0
# 22                           Action|Crime|Thriller       590.0
# 23                                    Drama|Sci-Fi      1561.0
# 24                                   Drama|Romance      8217.0
# 25                                           Drama       631.0
# 26                                  Children|Drama       233.0
# 27                                   Drama|Romance      1204.0
# 28          Adventure|Drama|Fantasy|Mystery|Sci-Fi      3884.0
# 29                                     Crime|Drama       339.0
# ...                                            ...         ...
# 22854                             Animation|Comedy         1.0
# 22855                                       Comedy         1.0
# 22856                                       Comedy         1.0
# 22857                             Comedy|Drama|War         1.0
# 22858                                        Drama         1.0
# 22859                                       Comedy         1.0
# 22860                             Animation|Comedy         1.0
# 22861                             Animation|Comedy         1.0
# 22862                               Comedy|Romance         1.0
# 22863                                       Comedy         1.0
# 22864                                       Comedy         1.0
# 22865                                       Comedy         0.0
# 22866                                       Comedy         1.0
# 22867                                        Drama         0.0
# 22868                                          War         0.0
# 22869                           (no genres listed)         0.0
# 22870                                        Drama         0.0
# 22871                                       Sci-Fi         0.0
# 22872                       Drama|Romance|Thriller         0.0
# 22873                                        Drama         0.0
# 22874                               Comedy|Romance         0.0
# 22875                                 Comedy|Drama         0.0
# 22876                               Comedy|Romance         0.0
# 22877                             Animation|Comedy         0.0
# 22878  Adventure|Animation|Children|Comedy|Fantasy         0.0
# 22879                                       Comedy         0.0
# 22880                                Comedy|Horror         0.0
# 22881                                       Comedy         0.0
# 22882                                       Comedy         0.0
# 22883                     Adventure|Fantasy|Horror         0.0
#
#                                                    notes
# 0      Toy Story (1995)<br>Adventure|Animation|Childr...
# 1      Jumanji (1995)<br>Adventure|Children|Fantasy<b...
# 2      Grumpier Old Men (1995)<br>Comedy|Romance<br>P...
# 3      Waiting to Exhale (1995)<br>Comedy|Drama|Roman...
# 4      Father of the Bride Part II (1995)<br>Comedy<b...
# 5      Heat (1995)<br>Action|Crime|Thriller<br>Popula...
# 6      Sabrina (1995)<br>Comedy|Romance<br>Popularity...
# 7      Tom and Huck (1995)<br>Adventure|Children<br>P...
# 8      Sudden Death (1995)<br>Action<br>Popularity:381.0
# 9      GoldenEye (1995)<br>Action|Adventure|Thriller<...
# 10     American President, The (1995)<br>Comedy|Drama...
# 11     Dracula: Dead and Loving It (1995)<br>Comedy|H...
# 12     Balto (1995)<br>Adventure|Animation|Children<b...
# 13            Nixon (1995)<br>Drama<br>Popularity:1343.0
# 14     Cutthroat Island (1995)<br>Action|Adventure|Ro...
# 15     Casino (1995)<br>Crime|Drama<br>Popularity:6218.0
# 16     Sense and Sensibility (1995)<br>Drama|Romance<...
# 17      Four Rooms (1995)<br>Comedy<br>Popularity:1221.0
# 18     Ace Ventura: When Nature Calls (1995)<br>Comed...
# 19     Money Train (1995)<br>Action|Comedy|Crime|Dram...
# 20     Get Shorty (1995)<br>Comedy|Crime|Thriller<br>...
# 21     Copycat (1995)<br>Crime|Drama|Horror|Mystery|T...
# 22     Assassins (1995)<br>Action|Crime|Thriller<br>P...
# 23     Powder (1995)<br>Drama|Sci-Fi<br>Popularity:15...
# 24     Leaving Las Vegas (1995)<br>Drama|Romance<br>P...
# 25           Othello (1995)<br>Drama<br>Popularity:631.0
# 26     Now and Then (1995)<br>Children|Drama<br>Popul...
# 27     Persuasion (1995)<br>Drama|Romance<br>Populari...
# 28     City of Lost Children, The (Cité des enfants p...
# 29     Shanghai Triad (Yao a yao yao dao waipo qiao) ...
# ...                                                  ...
# 22854  Kleines Arschloch - Der Film (1997)<br>Animati...
# 22855  Manta - Der Film (1991)<br>Comedy<br>Popularit...
# 22856    Girls on Top (2001)<br>Comedy<br>Popularity:1.0
# 22857  My Führer (2007)<br>Comedy|Drama|War<br>Popula...
# 22858  Stopped on Track (2011)<br>Drama<br>Popularity...
# 22859   Voll Normaaal (1994)<br>Comedy<br>Popularity:1.0
# 22860  Werner - Das muss kesseln!!! (1996)<br>Animati...
# 22861  Werner - Volles Rooäää (1999)<br>Animation|Com...
# 22862  What A Man (2011)<br>Comedy|Romance<br>Popular...
# 22863  7 Dwarves: The Forest Is Not Enough (2006)<br>...
# 22864  Die Bademeister – Weiber, saufen, Leben retten...
# 22865  Ants in the Pants 2 (2002)<br>Comedy<br>Popula...
# 22866    Manta, Manta (1991)<br>Comedy<br>Popularity:1.0
# 22867  Oscar and the Lady in Pink (2009)<br>Drama<br>...
# 22868      Vietnam in HD (2011)<br>War<br>Popularity:0.0
# 22869  WWII IN HD (2009)<br>(no genres listed)<br>Pop...
# 22870          Phoenix (2014)<br>Drama<br>Popularity:0.0
# 22871       Parallels (2015)<br>Sci-Fi<br>Popularity:0.0
# 22872  Gentlemen (2014)<br>Drama|Romance|Thriller<br>...
# 22873  A Second Chance (2014)<br>Drama<br>Popularity:0.0
# 22874  Standby (2014)<br>Comedy|Romance<br>Popularity...
# 22875  Three Quarter Moon (2011)<br>Comedy|Drama<br>P...
# 22876  Ants in the Pants (2000)<br>Comedy|Romance<br>...
# 22877  Werner - Gekotzt wird später (2003)<br>Animati...
# 22878  Brother Bear 2 (2006)<br>Adventure|Animation|C...
# 22879  No More School (2000)<br>Comedy<br>Popularity:0.0
# 22880  Forklift Driver Klaus: The First Day on the Jo...
# 22881  Kein Bund für's Leben (2007)<br>Comedy<br>Popu...
# 22882  Feuer, Eis & Dosenbier (2002)<br>Comedy<br>Pop...
# 22883  Innocence (2014)<br>Adventure|Fantasy|Horror<b...
#
# [22884 rows x 5 columns]

# %%
np.sum(R_train,axis=0).shape
# Out:
# (1, 22884)

# %%
params = {
    'models': {"PLRec": embedded_lrec_items,
               "PmiPLRec": pmi_lrec_items,
               "ALS": als
               },
    'alphas': 10,
    'rank': 100,
    'lambda': 0.01,
    'topK': 10,
    'iter': 7,
    'metric': ['R-Precision', 'NDCG'],
}

# %%
item_popularity = np.array(np.sum(R_train, axis=0)).flatten()

# %%
RQ_pmi = np.load('latent/U_{0}_{1}.npy'.format("PmiPLRec", params['rank']))
Y_pmi = np.load('latent/V_{0}_{1}.npy'.format("PmiPLRec", params['rank']))

# %% [markdown]
# NDCG:(0.2166897925036953, 0.0008172874169728984)
# R-Precision:(0.13134723220563294, 0.0006043677976043569)
# Recall@50:(0.27740511280609054, 0.001203150507462379)
# Clicks:(0.7533201203634049, 0.0077082474670282205)
# Precision@50:(0.14607444592326835, 0.0006567643132106959)
# Elapsed: 00:01:05

# %%
RQ_lrec = np.load('latent/U_{0}_{1}.npy'.format("PLRec", params['rank']))
Y_lrec = np.load('latent/V_{0}_{1}.npy'.format("PLRec", params['rank']))

# %% [markdown]
# NDCG:(0.1678184369426288, 0.0006633969240322184)
# R-Precision:(0.10747242788033418, 0.0005131395650126645)
# Recall@50:(0.20278737039541192, 0.0008773051481912347)
# Clicks:(0.90515595162317, 0.0084544466779494)
# Precision@50:(0.11765262426942887, 0.0005800609541356605)
# Elapsed: 00:01:01

# %%
RQ_als = np.load('latent/U_{0}_{1}.npy'.format("ALS", params['rank']))
Y_als = np.load('latent/V_{0}_{1}.npy'.format("ALS", params['rank']))

# %% [markdown]
# NDCG:(0.1830385913490645, 0.0007789548514031727)
# R-Precision:(0.10710897321868414, 0.0005531485311658711)
# Recall@50:(0.25291314842944895, 0.001255835182705188)
# Clicks:(0.9313407788901106, 0.00826187273725927)
# Precision@50:(0.12009359990741279, 0.0005156618276501792)
# Elapsed: 00:01:00

# %%
from sklearn.manifold import TSNE
import plotly.plotly as py
import plotly
plotly.tools.set_credentials_file(username='wuga', api_key='gJlTOHX9OA6h7rlUlkWo')
import plotly.graph_objs as go

# %% [markdown]
# ### Get Some User Records

# %%
R_valid = load_numpy(path=argpath, name=argvalid)

# %%
np.argpartition(-np.asarray(np.sum(R_train,axis=1)).reshape(-1)[np.asarray(np.sum(R_train,axis=1)).reshape(-1)>=2], 10)[:10]
# Out:
# array([117851, 125418,   8375,  82165, 131508, 131498,  20070,  78916,
#        130376,  54299])

# %%
can = np.argsort(np.asarray(np.sum(R_train,axis=1)).reshape(-1))
can[np.sort(np.asarray(np.sum(R_train,axis=1)).reshape(-1))>=5][:20]
# Out:
# array([ 87541,  96219,  99482,  70315,  69898,  12414,  12422, 102675,
#        113039,  10458,  69897, 112459,  12635, 113048,  70104,  87771,
#        112383,  69801,  70493,   8855])

# %%
R_train[13201].nonzero()[1]
# Out:
# array([  15, 4197], dtype=int32)

# %%
pd.set_option('display.max_colwidth', -1)

# %%
def getRecommendation(R_train, RQ, Y, index, k):
    user = RQ[index]
    idx = np.argsort(-Y.dot(user))
    filtered = np.delete(idx, np.isin(idx, R_train[index].nonzero()[1]).nonzero()[0])
    return Side_info['notes'].values[filtered][:k]

# %%
case = 129385
Side_info['notes'].values[R_train[case].nonzero()[1]]
# Out:
# array([u'Apollo 13 (1995)<br>Adventure|Drama|IMAX<br>Popularity:25913.0',
#        u'True Lies (1994)<br>Action|Adventure|Comedy|Romance|Thriller<br>Popularity:16725.0'],
#       dtype=object)

# %%
Side_info['notes'].values[R_valid[case].nonzero()[1]]
# Out:
# array([u'Outbreak (1995)<br>Action|Drama|Sci-Fi|Thriller<br>Popularity:7936.0',
#        u'Clear and Present Danger (1994)<br>Action|Crime|Drama|Thriller<br>Popularity:13092.0'],
#       dtype=object)

# %%
getRecommendation(R_train, RQ_pmi, Y_pmi, case, 5)
# Out:
# array([u'Clear and Present Danger (1994)<br>Action|Crime|Drama|Thriller<br>Popularity:13092.0',
#        u'Die Hard: With a Vengeance (1995)<br>Action|Crime|Thriller<br>Popularity:12631.0',
#        u'Speed (1994)<br>Action|Romance|Thriller<br>Popularity:12650.0',
#        u'Terminator 2: Judgment Day (1991)<br>Action|Sci-Fi<br>Popularity:24787.0',
#        u'While You Were Sleeping (1995)<br>Comedy|Romance<br>Popularity:7526.0'],
#       dtype=object)

# %%
getRecommendation(R_train, RQ_lrec, Y_lrec, case, 5)
# Out:
# array([u'GoldenEye (1995)<br>Action|Adventure|Thriller<br>Popularity:8914.0',
#        u'While You Were Sleeping (1995)<br>Comedy|Romance<br>Popularity:7526.0',
#        u'Beauty and the Beast (1991)<br>Animation|Children|Fantasy|Musical|Romance|IMAX<br>Popularity:15101.0',
#        u'L\xe9on: The Professional (a.k.a. The Professional) (L\xe9on) (1994)<br>Action|Crime|Drama|Thriller<br>Popularity:11163.0',
#        u'Die Hard: With a Vengeance (1995)<br>Action|Crime|Thriller<br>Popularity:12631.0'],
#       dtype=object)

# %%
getRecommendation(R_train, RQ_als, Y_als, case, 5)
# Out:
# array([u'Dances with Wolves (1990)<br>Adventure|Drama|Western<br>Popularity:20929.0',
#        u'Clear and Present Danger (1994)<br>Action|Crime|Drama|Thriller<br>Popularity:13092.0',
#        u'Fugitive, The (1993)<br>Thriller<br>Popularity:27495.0',
#        u'Aladdin (1992)<br>Adventure|Animation|Children|Comedy|Musical<br>Popularity:18780.0',
#        u'Beauty and the Beast (1991)<br>Animation|Children|Fantasy|Musical|Romance|IMAX<br>Popularity:15101.0'],
#       dtype=object)

# %%
np.argmin(x[x>2])
# Out:
# 0

# %%
case = 12414
Side_info['notes'].values[R_train[case].nonzero()[1]]
# Out:
# array([u'Die Hard: With a Vengeance (1995)<br>Action|Crime|Thriller<br>Popularity:12631.0',
#        u'Clear and Present Danger (1994)<br>Action|Crime|Drama|Thriller<br>Popularity:13092.0',
#        u'True Lies (1994)<br>Action|Adventure|Comedy|Romance|Thriller<br>Popularity:16725.0',
#        u'Jurassic Park (1993)<br>Action|Adventure|Sci-Fi|Thriller<br>Popularity:24316.0',
#        u'Beauty and the Beast (1991)<br>Animation|Children|Fantasy|Musical|Romance|IMAX<br>Popularity:15101.0'],
#       dtype=object)

# %%
Side_info['notes'].values[R_valid[case].nonzero()[1]]
# Out:
# array([u'Seven (a.k.a. Se7en) (1995)<br>Mystery|Thriller<br>Popularity:21370.0',
#        u'Braveheart (1995)<br>Action|Drama|War<br>Popularity:29159.0',
#        u'Star Trek: Generations (1994)<br>Adventure|Drama|Sci-Fi<br>Popularity:7914.0',
#        u'Firm, The (1993)<br>Drama|Thriller<br>Popularity:7270.0',
#        u'Terminator 2: Judgment Day (1991)<br>Action|Sci-Fi<br>Popularity:24787.0'],
#       dtype=object)

# %%
getRecommendation(R_train, RQ_pmi, Y_pmi, case, 5)
# Out:
# array([u'Aladdin (1992)<br>Adventure|Animation|Children|Comedy|Musical<br>Popularity:18780.0',
#        u'Crimson Tide (1995)<br>Drama|Thriller|War<br>Popularity:10241.0',
#        u'Stargate (1994)<br>Action|Adventure|Sci-Fi<br>Popularity:9789.0',
#        u'GoldenEye (1995)<br>Action|Adventure|Thriller<br>Popularity:8914.0',
#        u'Star Trek: Generations (1994)<br>Adventure|Drama|Sci-Fi<br>Popularity:7914.0'],
#       dtype=object)

# %%
getRecommendation(R_train, RQ_lrec, Y_lrec, case, 5)
# Out:
# array([u'Aladdin (1992)<br>Adventure|Animation|Children|Comedy|Musical<br>Popularity:18780.0',
#        u'Crimson Tide (1995)<br>Drama|Thriller|War<br>Popularity:10241.0',
#        u'Cliffhanger (1993)<br>Action|Adventure|Thriller<br>Popularity:5052.0',
#        u'Outbreak (1995)<br>Action|Drama|Sci-Fi|Thriller<br>Popularity:7936.0',
#        u'Die Hard (1988)<br>Action|Crime|Thriller<br>Popularity:13357.0'],
#       dtype=object)

# %%
getRecommendation(R_train, RQ_als, Y_als, case, 5)
# Out:
# array([u'Aladdin (1992)<br>Adventure|Animation|Children|Comedy|Musical<br>Popularity:18780.0',
#        u'Dances with Wolves (1990)<br>Adventure|Drama|Western<br>Popularity:20929.0',
#        u'Apollo 13 (1995)<br>Adventure|Drama|IMAX<br>Popularity:25913.0',
#        u'Fugitive, The (1993)<br>Thriller<br>Popularity:27495.0',
#        u'Batman (1989)<br>Action|Crime|Thriller<br>Popularity:15158.0'],
#       dtype=object)

# %%
case = 69801
Side_info['notes'].values[R_train[case].nonzero()[1]]
# Out:
# array([u'28 Days Later (2002)<br>Action|Horror|Sci-Fi<br>Popularity:4700.0',
#        u'Assassination of Richard Nixon, The (2004)<br>Crime|Drama|Thriller<br>Popularity:121.0',
#        u'Children of Men (2006)<br>Action|Adventure|Drama|Sci-Fi|Thriller<br>Popularity:3237.0',
#        u'Zodiac (2007)<br>Crime|Drama|Thriller<br>Popularity:943.0',
#        u'28 Weeks Later (2007)<br>Horror|Sci-Fi|Thriller<br>Popularity:1042.0'],
#       dtype=object)

# %%
Side_info['notes'].values[R_valid[case].nonzero()[1]]
# Out:
# array([u'Clockwork Orange, A (1971)<br>Crime|Drama|Sci-Fi|Thriller<br>Popularity:10989.0',
#        u'Shining, The (1980)<br>Horror<br>Popularity:10234.0',
#        u'Insider, The (1999)<br>Drama|Thriller<br>Popularity:3990.0',
#        u'Donnie Darko (2001)<br>Drama|Mystery|Sci-Fi|Thriller<br>Popularity:8788.0',
#        u'Machinist, The (Maquinista, El) (2004)<br>Mystery|Thriller<br>Popularity:1852.0'],
#       dtype=object)

# %%
getRecommendation(R_train, RQ_pmi, Y_pmi, case, 5)
# Out:
# array([u'Donnie Darko (2001)<br>Drama|Mystery|Sci-Fi|Thriller<br>Popularity:8788.0',
#        u'300 (2007)<br>Action|Fantasy|War|IMAX<br>Popularity:3919.0',
#        u'Shaun of the Dead (2004)<br>Comedy|Horror<br>Popularity:4388.0',
#        u'Sin City (2005)<br>Action|Crime|Film-Noir|Mystery|Thriller<br>Popularity:6412.0',
#        u'V for Vendetta (2006)<br>Action|Sci-Fi|Thriller|IMAX<br>Popularity:5717.0'],
#       dtype=object)

# %%
getRecommendation(R_train, RQ_lrec, Y_lrec, case, 5)
# Out:
# array([u'Donnie Darko (2001)<br>Drama|Mystery|Sci-Fi|Thriller<br>Popularity:8788.0',
#        u'300 (2007)<br>Action|Fantasy|War|IMAX<br>Popularity:3919.0',
#        u'Sin City (2005)<br>Action|Crime|Film-Noir|Mystery|Thriller<br>Popularity:6412.0',
#        u'V for Vendetta (2006)<br>Action|Sci-Fi|Thriller|IMAX<br>Popularity:5717.0',
#        u'Shaun of the Dead (2004)<br>Comedy|Horror<br>Popularity:4388.0'],
#       dtype=object)

# %%
getRecommendation(R_train, RQ_als, Y_als, case, 5)
# Out:
# array([u'300 (2007)<br>Action|Fantasy|War|IMAX<br>Popularity:3919.0',
#        u"Pan's Labyrinth (Laberinto del fauno, El) (2006)<br>Drama|Fantasy|Thriller<br>Popularity:4690.0",
#        u'Borat: Cultural Learnings of America for Make Benefit Glorious Nation of Kazakhstan (2006)<br>Comedy<br>Popularity:2117.0',
#        u'3:10 to Yuma (2007)<br>Action|Crime|Drama|Western<br>Popularity:1649.0',
#        u'Hot Fuzz (2007)<br>Action|Comedy|Crime|Mystery<br>Popularity:2550.0'],
#       dtype=object)
